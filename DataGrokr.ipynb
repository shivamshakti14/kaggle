# %%
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline

# %% [markdown]
# # Department Manager

# %%
# dept_manager=pd.read_csv('dept_manager.csv',converters={ 4: mdates.strpdate2num('%YY-%mm-%dd'), 5:mdates.strpdate2num('%YY-%mm-%dd')})
dept_manager=pd.read_csv('dept_manager.csv',index_col=['to_date','from_date'])#parse_dates=['to_date','from_date'],index_col=['to_date','from_date'])
dept_manager.plot()
plt.show()

# %%
dept_manager=pd.read_csv('dept_manager.csv')
count_nan = len(dept_manager) - dept_manager.count()
print count_nan
# Out:
# emp_no       0
# dept_no      0
# from_date    0
# to_date      0
# dtype: int64

# %% [markdown]
# # Department Employee

# %%
dept_emp = pd.read_csv('dept_emp.csv',dayfirst=True,index_col=['to_date','from_date'])
# dept_emp.describe
dept_emp.plot()
plt.show()

# %%
dept_emp = pd.read_csv('dept_emp.csv')
count_nan = len(dept_emp) - dept_emp.count()
print count_nan
# Out:
# emp_no       0
# dept_no      0
# from_date    0
# to_date      0
# dtype: int64

# %% [markdown]
# # Employee Titles

# %%
titles = pd.read_csv('titles.csv',dayfirst=True,index_col=['to_date','from_date'])
# titles.describe
titles.plot()
plt.show()

# %%
titles = pd.read_csv('titles.csv')
count_nan = len(titles) - titles.count()
print count_nan
# Out:
# emp_no       0
# title        0
# from_date    0
# to_date      0
# dtype: int64

# %% [markdown]
# # Departments

# %%
departments = pd.read_csv('departments.csv')#,dayfirst=True,index_col=['to_date','from_date'])
departments.describe
# Out:
# <bound method DataFrame.describe of         emp_no dept_no   from_date     to_date
# 0        10001    d005  1986-06-26  9999-01-01
# 1        10002    d007  1996-08-03  9999-01-01
# 2        10003    d004  1995-12-03  9999-01-01
# 3        10004    d004  1986-12-01  9999-01-01
# 4        10005    d003  1989-09-12  9999-01-01
# 5        10006    d005  1990-08-05  9999-01-01
# 6        10007    d008  1989-02-10  9999-01-01
# 7        10008    d005  1998-03-11  2000-07-31
# 8        10009    d006  1985-02-18  9999-01-01
# 9        10010    d004  1996-11-24  2000-06-26
# 10       10010    d006  2000-06-26  9999-01-01
# 11       10011    d009  1990-01-22  1996-11-09
# 12       10012    d005  1992-12-18  9999-01-01
# 13       10013    d003  1985-10-20  9999-01-01
# 14       10014    d005  1993-12-29  9999-01-01
# 15       10015    d008  1992-09-19  1993-08-22
# 16       10016    d007  1998-02-11  9999-01-01
# 17       10017    d001  1993-08-03  9999-01-01
# ...

# %%
count_nan = len(departments) - departments.count()
print count_nan
# Out:
# dept_no      0
# dept_name    0
# dtype: int64

# %% [markdown]
# # Salaries

# %%
salaries = pd.read_csv('salaries.csv',dayfirst=True,index_col=['to_date','from_date'])
# salaries.describe
salaries.plot()
plt.show()

# %%
salaries = pd.read_csv('salaries.csv')
count_nan = len(salaries) - salaries.count()
print count_nan
# Out:
# emp_no       0
# salary       0
# from_date    0
# to_date      0
# dtype: int64
